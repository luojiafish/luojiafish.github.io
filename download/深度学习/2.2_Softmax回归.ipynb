# %% [markdown]
# ## Softmax回归和线性回归的区别
# 线性回归是预测连续实数值，拟合函数值吗
#
# softmax则是预测概率，让真类比其他类大就行
#
# **交叉熵/极大似然**的训练目标才是它与线性回归真正不同的核心。

# %% [markdown]
# ## 交叉熵损失函数
#
# 假设训练数据集的样本数为$n$，交叉熵损失函数定义为
# $$\ell(\boldsymbol{\Theta}) = \frac{1}{n} \sum_{i=1}^n H\left(\boldsymbol y^{(i)}, \boldsymbol {\hat y}^{(i)}\right ),$$
# $$H\left(\boldsymbol y^{(i)}, \boldsymbol {\hat y}^{(i)}\right ) = -\sum_{j=1}^q y_j^{(i)} \log \hat y_j^{(i)},$$
# 如果每个样本只有一个标签($\boldsymbol y_j^{(i)}为1，其余为0$)，那么交叉熵损失可以简写成:
# $$\ell(\boldsymbol{\Theta}) = -(1/n)  \sum_{i=1}^n \log \hat y_{y^{(i)}}^{(i)}$$

# %%
# zip不打包可以读出来吗，2.多线程加速的设置如何才合理，一个个尝试吗，直到在相同bs时，线程增加不会加快时间
