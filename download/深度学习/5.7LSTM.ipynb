# %% [markdown]
# > 与 GRU 相比，LSTM 显式区分了记忆细胞 ($c_t$) 与隐藏状态 ($h_t$)，并通过互相独立的遗忘门和输入门对记忆更新进行更细粒度的控制，同时引入输出门调节从记忆到隐藏状态的读出过程；而 GRU 将记忆与隐藏状态合并为单一的 ($h_t$)，使用一对互补的门控系数 (($1-z_t, z_t$)) 在旧状态与候选状态之间做凸组合，结构更为紧凑但自由度相对较低。
